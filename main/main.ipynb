# %%
# Pipeline do projeto (notebooks por etapa)

**Próximos passos:** se você **validou a etapa 1 (EDA)**, trabalhe em [02 — valores ausentes](notebooks/02_valores_ausentes.ipynb). Se a **etapa 2** já estiver validada, avance para [03 — outliers](notebooks/03_outliers.ipynb).

Execute na ordem, **validando cada etapa** antes da seguinte:

1. [`notebooks/00_config_e_amostra.ipynb`](notebooks/00_config_e_amostra.ipynb) — caminhos, amostra estratificada, cache Parquet  
2. [`notebooks/01_estatistica_eda.ipynb`](notebooks/01_estatistica_eda.ipynb) — EDA e estatística descritiva  
3. [`notebooks/02_valores_ausentes.ipynb`](notebooks/02_valores_ausentes.ipynb) — ausentes e completude  
4. [`notebooks/03_outliers.ipynb`](notebooks/03_outliers.ipynb) — outliers (IQR, z-score, Isolation Forest)  
5. [`notebooks/04_preprocessamento_encoding.ipynb`](notebooks/04_preprocessamento_encoding.ipynb) — pré-processamento e encoding  
6. [`notebooks/05_pipeline_modelo.ipynb`](notebooks/05_pipeline_modelo.ipynb) — pipeline sklearn e baseline  

Dependências: `pip install -r requirements.txt` na raiz do repositório.

Cada notebook termina com uma **pausa para validação** e checklist antes de avançar.
